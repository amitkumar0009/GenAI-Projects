# %%
import os
from dotenv import load_dotenv
load_dotenv()

groq_api_key=os.getenv("GROQ_API_KEY")

# %%
from langchain_groq import ChatGroq

# groq_api_key = "YOUR_API_KEY_HERE"  # or read from env
model=ChatGroq(model="llama-3.3-70b-versatile",groq_api_key=groq_api_key)

# %%
from langchain_core.messages import HumanMessage
model.invoke([HumanMessage(content="Hello, how are you?")])
# Out:
# AIMessage(content="Hello. I'm just a language model, so I don't have feelings or emotions like humans do, but I'm functioning properly and ready to assist you with any questions or topics you'd like to discuss. How can I help you today?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 50, 'prompt_tokens': 41, 'total_tokens': 91, 'completion_time': 0.105399002, 'completion_tokens_details': None, 'prompt_time': 0.002496272, 'prompt_tokens_details': None, 'queue_time': 0.053032948, 'total_time': 0.107895274}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019b0a22-226d-77d2-adfe-9f65bec43aa0-0', usage_metadata={'input_tokens': 41, 'output_tokens': 50, 'total_tokens': 91})
